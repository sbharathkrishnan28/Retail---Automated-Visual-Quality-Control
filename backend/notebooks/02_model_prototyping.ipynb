# %% [markdown]
# # 02. Core Model Prototyping
#
# This notebook experiments with Transfer Learning using ResNet50 and MobileNetV2 architectures.

# %%
from tensorflow.keras.applications import ResNet50, MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# TODO: Build base model, freeze layers, and train custom classification head

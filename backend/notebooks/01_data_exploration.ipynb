# %% [markdown]
# # 01. Data Exploration and Augmentation
#
# This notebook focuses on visualizing the distribution of pass/defect PCBs and testing the `ImageDataGenerator` augmentations.

# %%
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# TODO: Load dataset and visualize sample augmentations

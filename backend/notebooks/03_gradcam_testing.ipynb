# %% [markdown]
# # 03. Grad-CAM Testing
#
# This notebook prototypes visual explainability heatmaps using Gradient-weighted Class Activation Mapping (Grad-CAM).

# %%
import numpy as np
import tensorflow as tf
import cv2

# TODO: Implement Grad-CAM algorithm and overlay heatmap on test images
